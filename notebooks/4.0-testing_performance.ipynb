# %% [markdown]
# # Cache Impact Benchmark
# This notebook measures the latency difference between cache-disabled and cache-enabled runs of the Terminal C runtime pipeline.

# %%
import time
from pathlib import Path
import pandas as pd
from IPython.display import display
import os
import sys

PROJECT_NAME = "terminalC"
PROJECT_DIR = os.path.join(os.path.abspath('.').split(PROJECT_NAME)[0], PROJECT_NAME)
sys.path.append(PROJECT_DIR)

from terminalc.runtime_core.pipelines.runtime_pipeline import RuntimePipeline
from terminalc.runtime_core.config import load_runtime_config
from terminalc.runtime_core.pipelines.llm_client import LocalTransformersClient

# %%
PROMPT_SCENARIOS = [
    {
        "name": "btc_close_variants",
        "focus": "query_cache",
        "description": "Same BTC close query phrased differently to stress the DuckDB query cache.",
        "prompts": [
            "What was the closing price of BTC on Oct 15, 2025?",
            "Give me the closing price of BTC on Oct 15, 2025.",
        ],
    },
    {
        "name": "btc_ohlc_variants",
        "focus": "query_cache",
        "description": "Two phrasings that need the same OHLC window so only the query cache should help.",
        "prompts": [
            "List the open, high, low, and close prices for BTC between Oct 15 and Oct 17, 2025.",
            "Show BTC's OHLC candles between Oct 15 and Oct 17, 2025.",
        ],
    },
    {
        "name": "sol_ada_high_variants",
        "focus": "query_cache",
        "description": "SOL vs ADA high comparison asked twice with different wording.",
        "prompts": [
            "Which asset had the highest high on Oct 20, 2025: SOL or ADA?",
            "Between SOL and ADA, who posted the higher high on Oct 20, 2025?",
        ],
    },
    {
        "name": "btc_news_repeat",
        "focus": "prompt_cache",
        "description": "Exact duplicate news briefing to highlight prompt cache hits.",
        "prompts": [
            "Summarize the news for Bitcoin between Nov 1, 2025 and Nov 7, 2025.",
            "Summarize the news for Bitcoin between Nov 1, 2025 and Nov 7, 2025.",
        ],
    },
    {
        "name": "btc_trend_repeat",
        "focus": "prompt_cache",
        "description": "Identical technical analysis request repeated twice.",
        "prompts": [
            "Analyze BTC's trend on Nov 1, 2025 using both price action and RSI.",
            "Analyze BTC's trend on Nov 1, 2025 using both price action and RSI.",
        ],
    },
    {
        "name": "allocation_repeat",
        "focus": "prompt_cache",
        "description": "Capital allocation instruction repeated word-for-word.",
        "prompts": [
            "If I have 10,000 USD to deploy right now, how would you distribute it across BTC, ETH, and SOL based on the past month's signals and why?",
            "If I have 10,000 USD to deploy right now, how would you distribute it across BTC, ETH, and SOL based on the past month's signals and why?",
        ],
    },
]

SCENARIO_OVERVIEW = pd.DataFrame(
    [
        {
            "scenario": scenario["name"],
            "focus": scenario["focus"],
            "description": scenario["description"],
            "prompt_count": len(scenario["prompts"]),
        }
        for scenario in PROMPT_SCENARIOS
    ]
)

PROMPT_TESTS = [
    {
        "scenario": scenario["name"],
        "focus": scenario["focus"],
        "variant": idx + 1,
        "prompt": prompt,
    }
    for scenario in PROMPT_SCENARIOS
    for idx, prompt in enumerate(scenario["prompts"])
]

CACHE_MODES = [
    {"name": "no_cache", "query_cache_enabled": False, "prompt_cache_enabled": False},
    {"name": "query_cache_only", "query_cache_enabled": True, "prompt_cache_enabled": False},
    {"name": "prompt_cache_only", "query_cache_enabled": False, "prompt_cache_enabled": True},
    {"name": "all_caches", "query_cache_enabled": True, "prompt_cache_enabled": True},
]


def clear_cache_dir(path: Path) -> None:
    path = Path(path)
    path.mkdir(parents=True, exist_ok=True)
    for item in path.iterdir():
        if item.is_file():
            item.unlink()


def clear_prompt_cache(cfg) -> None:
    clear_cache_dir(cfg.cache.prompt_cache_dir)


def clear_query_cache(cfg) -> None:
    clear_cache_dir(cfg.cache.query_cache_dir)


def clear_all_caches(cfg) -> None:
    clear_query_cache(cfg)
    clear_prompt_cache(cfg)


def resolve_small_model_path(cfg) -> Path | None:
    endpoint = cfg.models.small_model_endpoint
    if not endpoint:
        return None
    local_root = cfg.models.local_model_dir
    local_root_path = local_root if isinstance(local_root, Path) else Path(local_root)
    candidate = local_root_path / endpoint.replace("/", os.sep)
    model_path = candidate if candidate.exists() else local_root_path / endpoint
    model_path = model_path.resolve()
    return model_path if model_path.exists() else None


def build_small_client(cfg, use_adapter: bool) -> LocalTransformersClient:
    model_path = resolve_small_model_path(cfg)
    if model_path is None:
        raise FileNotFoundError("Small model weights are not available locally.")
    adapter_path = cfg.models.small_model_adapter_dir if use_adapter else None
    return LocalTransformersClient(str(model_path), adapter_path=str(adapter_path) if adapter_path else None)


def available_model_variants(cfg) -> list[str]:
    variants: list[str] = []
    if '018219422' in PROJECT_DIR:
        if resolve_small_model_path(cfg):
            variants.append("small")
            if cfg.models.small_model_adapter_dir:
                variants.append("small_lora")
    else:
        if cfg.models.large_model_endpoint:
            variants.append("large")
    return variants

def build_pipeline_for_variant(model_variant: str, cfg) -> RuntimePipeline:
    if model_variant == "small":
        small_client = build_small_client(cfg, use_adapter=False)
        return RuntimePipeline(model_type=None, llm_client=small_client, config=cfg)
    if model_variant == "small_lora":
        return RuntimePipeline(model_type="small", config=cfg)
    return RuntimePipeline(model_type=model_variant, config=cfg)


def measure_latency(pipeline, prompt_tests, cfg, *, query_cache_enabled: bool = True, prompt_cache_enabled: bool = True):
    rows = []
    for test in prompt_tests:
        if not query_cache_enabled:
            clear_query_cache(cfg)
        if not prompt_cache_enabled:
            clear_prompt_cache(cfg)
        start = time.perf_counter()
        result = pipeline.run(test["prompt"])
        elapsed = time.perf_counter() - start
        rows.append(
            {
                "prompt": test["prompt"],
                "scenario": test["scenario"],
                "focus": test["focus"],
                "variant": test["variant"],
                "latency_sec": elapsed,
                "model_name": result.model_name,
            }
        )
    return pd.DataFrame(rows)

# %%
cfg = load_runtime_config()
model_variants = available_model_variants(cfg)
if not model_variants:
    raise RuntimeError("No configured models available for benchmarking.")

print("Benchmarking models:", ", ".join(model_variants))
display(SCENARIO_OVERVIEW)

result_frames = []

for model_variant in model_variants:
    for cache_mode in CACHE_MODES:
        clear_all_caches(cfg)
        pipeline = build_pipeline_for_variant(model_variant, cfg)
        df = measure_latency(
            pipeline,
            PROMPT_TESTS,
            cfg=cfg,
            query_cache_enabled=cache_mode["query_cache_enabled"],
            prompt_cache_enabled=cache_mode["prompt_cache_enabled"],
        )
        df = df.assign(
            model_variant=model_variant,
            cache_mode=cache_mode["name"],
            query_cache_enabled=cache_mode["query_cache_enabled"],
            prompt_cache_enabled=cache_mode["prompt_cache_enabled"],
        )
        result_frames.append(df)

results = pd.concat(result_frames, ignore_index=True)
display(results)

scenario_summary = (
    results.groupby(["model_variant", "cache_mode", "focus", "scenario", "variant"])["latency_sec"]
    .mean()
    .reset_index()
)
display(scenario_summary)

cache_summary = (
    results.groupby(["model_variant", "cache_mode"])["latency_sec"]
    .agg(["mean", "median", "min", "max", "count"])
    .reset_index()
)
display(cache_summary)

results.to_csv(f"{PROJECT_DIR}/results/cache_test_result/large_cache_results.csv")
# Out:
# Benchmarking models: large
#                 scenario         focus  \
# 0     btc_close_variants   query_cache
# 1      btc_ohlc_variants   query_cache
# 2  sol_ada_high_variants   query_cache
# 3        btc_news_repeat  prompt_cache
# 4       btc_trend_repeat  prompt_cache
# 5      allocation_repeat  prompt_cache
#
#                                          description  prompt_count
# 0  Same BTC close query phrased differently to st...             2
# 1  Two phrasings that need the same OHLC window s...             2
# 2  SOL vs ADA high comparison asked twice with di...             2
# 3  Exact duplicate news briefing to highlight pro...             2
# 4  Identical technical analysis request repeated ...             2
# 5  Capital allocation instruction repeated word-f...             2
#                                                prompt               scenario  \
# 0   What was the closing price of BTC on Oct 15, 2...     btc_close_variants
# 1   Give me the closing price of BTC on Oct 15, 2025.     btc_close_variants
# 2   List the open, high, low, and close prices for...      btc_ohlc_variants
# 3   Show BTC's OHLC candles between Oct 15 and Oct...      btc_ohlc_variants
# 4   Which asset had the highest high on Oct 20, 20...  sol_ada_high_variants
# 5   Between SOL and ADA, who posted the higher hig...  sol_ada_high_variants
# 6   Summarize the news for Bitcoin between Nov 1, ...        btc_news_repeat
# 7   Summarize the news for Bitcoin between Nov 1, ...        btc_news_repeat
# 8   Analyze BTC's trend on Nov 1, 2025 using both ...       btc_trend_repeat
# 9   Analyze BTC's trend on Nov 1, 2025 using both ...       btc_trend_repeat
# 10  If I have 10,000 USD to deploy right now, how ...      allocation_repeat
# 11  If I have 10,000 USD to deploy right now, how ...      allocation_repeat
# 12  What was the closing price of BTC on Oct 15, 2...     btc_close_variants
# 13  Give me the closing price of BTC on Oct 15, 2025.     btc_close_variants
# 14  List the open, high, low, and close prices for...      btc_ohlc_variants
# 15  Show BTC's OHLC candles between Oct 15 and Oct...      btc_ohlc_variants
# 16  Which asset had the highest high on Oct 20, 20...  sol_ada_high_variants
# 17  Between SOL and ADA, who posted the higher hig...  sol_ada_high_variants
# 18  Summarize the news for Bitcoin between Nov 1, ...        btc_news_repeat
# 19  Summarize the news for Bitcoin between Nov 1, ...        btc_news_repeat
# 20  Analyze BTC's trend on Nov 1, 2025 using both ...       btc_trend_repeat
# 21  Analyze BTC's trend on Nov 1, 2025 using both ...       btc_trend_repeat
# 22  If I have 10,000 USD to deploy right now, how ...      allocation_repeat
# 23  If I have 10,000 USD to deploy right now, how ...      allocation_repeat
# 24  What was the closing price of BTC on Oct 15, 2...     btc_close_variants
# 25  Give me the closing price of BTC on Oct 15, 2025.     btc_close_variants
# 26  List the open, high, low, and close prices for...      btc_ohlc_variants
# 27  Show BTC's OHLC candles between Oct 15 and Oct...      btc_ohlc_variants
# 28  Which asset had the highest high on Oct 20, 20...  sol_ada_high_variants
# 29  Between SOL and ADA, who posted the higher hig...  sol_ada_high_variants
# 30  Summarize the news for Bitcoin between Nov 1, ...        btc_news_repeat
# 31  Summarize the news for Bitcoin between Nov 1, ...        btc_news_repeat
# 32  Analyze BTC's trend on Nov 1, 2025 using both ...       btc_trend_repeat
# 33  Analyze BTC's trend on Nov 1, 2025 using both ...       btc_trend_repeat
# 34  If I have 10,000 USD to deploy right now, how ...      allocation_repeat
# 35  If I have 10,000 USD to deploy right now, how ...      allocation_repeat
# 36  What was the closing price of BTC on Oct 15, 2...     btc_close_variants
# 37  Give me the closing price of BTC on Oct 15, 2025.     btc_close_variants
# 38  List the open, high, low, and close prices for...      btc_ohlc_variants
# 39  Show BTC's OHLC candles between Oct 15 and Oct...      btc_ohlc_variants
# 40  Which asset had the highest high on Oct 20, 20...  sol_ada_high_variants
# 41  Between SOL and ADA, who posted the higher hig...  sol_ada_high_variants
# 42  Summarize the news for Bitcoin between Nov 1, ...        btc_news_repeat
# 43  Summarize the news for Bitcoin between Nov 1, ...        btc_news_repeat
# 44  Analyze BTC's trend on Nov 1, 2025 using both ...       btc_trend_repeat
# 45  Analyze BTC's trend on Nov 1, 2025 using both ...       btc_trend_repeat
# 46  If I have 10,000 USD to deploy right now, how ...      allocation_repeat
# 47  If I have 10,000 USD to deploy right now, how ...      allocation_repeat
#
#            focus  variant  latency_sec  \
# 0    query_cache        1     5.554118
# 1    query_cache        2     5.342233
# 2    query_cache        1     7.142040
# 3    query_cache        2     8.213021
# 4    query_cache        1     3.460927
# 5    query_cache        2     4.476927
# 6   prompt_cache        1    20.564779
# 7   prompt_cache        2    14.548347
# 8   prompt_cache        1     6.860895
# 9   prompt_cache        2     7.452122
# 10  prompt_cache        1    17.450482
# 11  prompt_cache        2    20.503282
# 12   query_cache        1     7.083980
# 13   query_cache        2     3.925245
# 14   query_cache        1     9.933497
# 15   query_cache        2     7.688693
# 16   query_cache        1     6.846594
# 17   query_cache        2     4.936689
# 18  prompt_cache        1    12.642794
# 19  prompt_cache        2     9.005675
# 20  prompt_cache        1     9.515456
# 21  prompt_cache        2     7.413806
# 22  prompt_cache        1     7.321104
# 23  prompt_cache        2     6.361251
# 24   query_cache        1     4.077824
# 25   query_cache        2     3.745399
# 26   query_cache        1     5.613433
# 27   query_cache        2     5.985954
# 28   query_cache        1     3.493861
# 29   query_cache        2     3.796031
# 30  prompt_cache        1    14.172837
# 31  prompt_cache        2     0.023399
# 32  prompt_cache        1     6.071478
# 33  prompt_cache        2     0.030604
# 34  prompt_cache        1    19.630291
# 35  prompt_cache        2     0.044294
# 36   query_cache        1     7.219842
# 37   query_cache        2     4.152852
# 38   query_cache        1     7.390261
# 39   query_cache        2     7.718829
# 40   query_cache        1     3.833904
# 41   query_cache        2     3.581360
# 42  prompt_cache        1    13.341009
# 43  prompt_cache        2     0.012510
# 44  prompt_cache        1     9.995170
# 45  prompt_cache        2     0.004818
# 46  prompt_cache        1    13.894902
# 47  prompt_cache        2     0.014491
#
#                                     model_name model_variant  \
# 0   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 1   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 2   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 3   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 4   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 5   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 6   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 7   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 8   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 9   meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 10  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 11  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 12  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 13  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 14  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 15  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 16  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 17  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 18  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 19  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 20  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 21  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 22  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 23  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 24  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 25  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 26  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 27  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 28  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 29  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 30  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 31  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 32  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 33  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 34  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 35  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 36  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 37  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 38  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 39  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 40  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 41  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 42  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 43  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 44  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 45  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 46  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
# 47  meta-llama/Llama-3.3-70B-Instruct:cheapest         large
#
#            cache_mode  query_cache_enabled  prompt_cache_enabled
# 0            no_cache                False                 False
# 1            no_cache                False                 False
# 2            no_cache                False                 False
# 3            no_cache                False                 False
# 4            no_cache                False                 False
# 5            no_cache                False                 False
# 6            no_cache                False                 False
# 7            no_cache                False                 False
# 8            no_cache                False                 False
# 9            no_cache                False                 False
# 10           no_cache                False                 False
# 11           no_cache                False                 False
# 12   query_cache_only                 True                 False
# 13   query_cache_only                 True                 False
# 14   query_cache_only                 True                 False
# 15   query_cache_only                 True                 False
# 16   query_cache_only                 True                 False
# 17   query_cache_only                 True                 False
# 18   query_cache_only                 True                 False
# 19   query_cache_only                 True                 False
# 20   query_cache_only                 True                 False
# 21   query_cache_only                 True                 False
# 22   query_cache_only                 True                 False
# 23   query_cache_only                 True                 False
# 24  prompt_cache_only                False                  True
# 25  prompt_cache_only                False                  True
# 26  prompt_cache_only                False                  True
# 27  prompt_cache_only                False                  True
# 28  prompt_cache_only                False                  True
# 29  prompt_cache_only                False                  True
# 30  prompt_cache_only                False                  True
# 31  prompt_cache_only                False                  True
# 32  prompt_cache_only                False                  True
# 33  prompt_cache_only                False                  True
# 34  prompt_cache_only                False                  True
# 35  prompt_cache_only                False                  True
# 36         all_caches                 True                  True
# 37         all_caches                 True                  True
# 38         all_caches                 True                  True
# 39         all_caches                 True                  True
# 40         all_caches                 True                  True
# 41         all_caches                 True                  True
# 42         all_caches                 True                  True
# 43         all_caches                 True                  True
# 44         all_caches                 True                  True
# 45         all_caches                 True                  True
# 46         all_caches                 True                  True
# 47         all_caches                 True                  True
#    model_variant         cache_mode         focus               scenario  \
# 0          large         all_caches  prompt_cache      allocation_repeat
# 1          large         all_caches  prompt_cache      allocation_repeat
# 2          large         all_caches  prompt_cache        btc_news_repeat
# 3          large         all_caches  prompt_cache        btc_news_repeat
# 4          large         all_caches  prompt_cache       btc_trend_repeat
# 5          large         all_caches  prompt_cache       btc_trend_repeat
# 6          large         all_caches   query_cache     btc_close_variants
# 7          large         all_caches   query_cache     btc_close_variants
# 8          large         all_caches   query_cache      btc_ohlc_variants
# 9          large         all_caches   query_cache      btc_ohlc_variants
# 10         large         all_caches   query_cache  sol_ada_high_variants
# 11         large         all_caches   query_cache  sol_ada_high_variants
# 12         large           no_cache  prompt_cache      allocation_repeat
# 13         large           no_cache  prompt_cache      allocation_repeat
# 14         large           no_cache  prompt_cache        btc_news_repeat
# 15         large           no_cache  prompt_cache        btc_news_repeat
# 16         large           no_cache  prompt_cache       btc_trend_repeat
# 17         large           no_cache  prompt_cache       btc_trend_repeat
# 18         large           no_cache   query_cache     btc_close_variants
# 19         large           no_cache   query_cache     btc_close_variants
# 20         large           no_cache   query_cache      btc_ohlc_variants
# 21         large           no_cache   query_cache      btc_ohlc_variants
# 22         large           no_cache   query_cache  sol_ada_high_variants
# 23         large           no_cache   query_cache  sol_ada_high_variants
# 24         large  prompt_cache_only  prompt_cache      allocation_repeat
# 25         large  prompt_cache_only  prompt_cache      allocation_repeat
# 26         large  prompt_cache_only  prompt_cache        btc_news_repeat
# 27         large  prompt_cache_only  prompt_cache        btc_news_repeat
# 28         large  prompt_cache_only  prompt_cache       btc_trend_repeat
# 29         large  prompt_cache_only  prompt_cache       btc_trend_repeat
# 30         large  prompt_cache_only   query_cache     btc_close_variants
# 31         large  prompt_cache_only   query_cache     btc_close_variants
# 32         large  prompt_cache_only   query_cache      btc_ohlc_variants
# 33         large  prompt_cache_only   query_cache      btc_ohlc_variants
# 34         large  prompt_cache_only   query_cache  sol_ada_high_variants
# 35         large  prompt_cache_only   query_cache  sol_ada_high_variants
# 36         large   query_cache_only  prompt_cache      allocation_repeat
# 37         large   query_cache_only  prompt_cache      allocation_repeat
# 38         large   query_cache_only  prompt_cache        btc_news_repeat
# 39         large   query_cache_only  prompt_cache        btc_news_repeat
# 40         large   query_cache_only  prompt_cache       btc_trend_repeat
# 41         large   query_cache_only  prompt_cache       btc_trend_repeat
# 42         large   query_cache_only   query_cache     btc_close_variants
# 43         large   query_cache_only   query_cache     btc_close_variants
# 44         large   query_cache_only   query_cache      btc_ohlc_variants
# 45         large   query_cache_only   query_cache      btc_ohlc_variants
# 46         large   query_cache_only   query_cache  sol_ada_high_variants
# 47         large   query_cache_only   query_cache  sol_ada_high_variants
#
#     variant  latency_sec
# 0         1    13.894902
# 1         2     0.014491
# 2         1    13.341009
# 3         2     0.012510
# 4         1     9.995170
# 5         2     0.004818
# 6         1     7.219842
# 7         2     4.152852
# 8         1     7.390261
# 9         2     7.718829
# 10        1     3.833904
# 11        2     3.581360
# 12        1    17.450482
# 13        2    20.503282
# 14        1    20.564779
# 15        2    14.548347
# 16        1     6.860895
# 17        2     7.452122
# 18        1     5.554118
# 19        2     5.342233
# 20        1     7.142040
# 21        2     8.213021
# 22        1     3.460927
# 23        2     4.476927
# 24        1    19.630291
# 25        2     0.044294
# 26        1    14.172837
# 27        2     0.023399
# 28        1     6.071478
# 29        2     0.030604
# 30        1     4.077824
# 31        2     3.745399
# 32        1     5.613433
# 33        2     5.985954
# 34        1     3.493861
# 35        2     3.796031
# 36        1     7.321104
# 37        2     6.361251
# 38        1    12.642794
# 39        2     9.005675
# 40        1     9.515456
# 41        2     7.413806
# 42        1     7.083980
# 43        2     3.925245
# 44        1     9.933497
# 45        2     7.688693
# 46        1     6.846594
# 47        2     4.936689
#   model_variant         cache_mode       mean    median       min        max  \
# 0         large         all_caches   5.929996  5.686347  0.004818  13.894902
# 1         large           no_cache  10.130764  7.297081  3.460927  20.564779
# 2         large  prompt_cache_only   5.557117  3.936927  0.023399  19.630291
# 3         large   query_cache_only   7.722899  7.367455  3.925245  12.642794
#
#    count
# 0     12
# 1     12
# 2     12
# 3     12
