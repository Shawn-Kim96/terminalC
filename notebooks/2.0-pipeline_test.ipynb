# %%
import os
import sys

PROJECT_NAME = "terminalC"
PROJECT_DIR = os.path.join(os.path.abspath('.').split(PROJECT_NAME)[0], PROJECT_NAME)
sys.path.append(PROJECT_DIR)

# %% [markdown]
# # Input analyzer

# %%
from src.runtime_core.test.test_input_analyzer import test_input_analyzer

prompts = [
    "Which assets delivered the highest and lowest returns at Oct 15, 2025?",
    "What coins are attractive to buy in terms of technical indicators?",
    "Summarize BTC news this week and tell me if the sentiment is positive.",
    "What momentum strategy rules are available for ETH right now?",
    "Give me some startegies I can use for trading."
]

test_input_analyzer(prompts)
# Out:
# === Prompt ===
# Which assets delivered the highest and lowest returns at Oct 15, 2025?
# --- Intent ---
# {
#     "name": "market_price",
#     "confidence": 0.75,
#     "parameters": {
#         "raw": "Which assets delivered the highest and lowest returns at Oct 15, 2025?",
#         "filters": {
#             "start_date": "2025-10-15",
#             "end_date": "2025-10-15"
#         },
#         "metrics": [
#             "price"
#         ],
#         "prompt_flags": []
#     },
#     "slots": {
#         "asset_scope": {
#             "scope": "all_assets",
#             "symbols": [],
#             "raw_mentions": []
#         },
#         "time_scope": {
#             "start_date": "2025-10-15",
#             "end_date": "2025-10-15",
#             "relative": null,
#             "raw_text": "explicit_dates"
#         },
#         "timeframe": null,
#         "metrics": [
#             "price"
#         ],
#         "strategy_topics": [],
#         "news_filters": {
#             "categories": [],
#             "sentiments": []
#         },
#         "prompt_flags": []
#     }
# }
#
# === Prompt ===
# What coins are attractive to buy in terms of technical indicators?
# --- Intent ---
# {
#     "name": "multi_context",
#     "confidence": 0.7,
#     "parameters": {
#         "raw": "What coins are attractive to buy in terms of technical indicators?",
#         "metrics": [
#             "signal"
#         ],
#         "prompt_flags": []
#     },
#     "slots": {
#         "asset_scope": {
#             "scope": "all_assets",
#             "symbols": [],
#             "raw_mentions": []
#         },
#         "time_scope": {
#             "start_date": null,
#             "end_date": null,
#             "relative": null,
#             "raw_text": null
#         },
#         "timeframe": null,
#         "metrics": [
#             "signal"
#         ],
#         "strategy_topics": [],
#         "news_filters": {
#             "categories": [],
#             "sentiments": []
#         },
#         "prompt_flags": []
#     }
# }
#
# === Prompt ===
# Summarize BTC news this week and tell me if the sentiment is positive.
# --- Intent ---
# {
#     "name": "news_context",
#     "confidence": 0.85,
#     "parameters": {
#         "raw": "Summarize BTC news this week and tell me if the sentiment is positive.",
#         "filters": {
#             "symbol": [
#                 "BTC"
#             ],
#             "relative_range": "this_week"
#         },
#         "metrics": [
#             "news_sentiment"
#         ],
#         "prompt_flags": []
#     },
#     "slots": {
#         "asset_scope": {
#             "scope": "specific_asset",
#             "symbols": [
#                 "BTC"
#             ],
#             "raw_mentions": [
#                 "btc"
#             ]
#         },
#         "time_scope": {
#             "start_date": null,
#             "end_date": null,
#             "relative": "this_week",
#             "raw_text": "this week"
#         },
#         "timeframe": null,
#         "metrics": [
#             "news_sentiment"
#         ],
#         "strategy_topics": [],
#         "news_filters": {
#             "categories": [],
#             "sentiments": [
#                 "positive"
#             ]
#         },
#         "prompt_flags": []
#     }
# }
#
# === Prompt ===
# What momentum strategy rules are available for ETH right now?
# --- Intent ---
# {
#     "name": "multi_context",
#     "confidence": 0.7,
#     "parameters": {
#         "raw": "What momentum strategy rules are available for ETH right now?",
#         "filters": {
#             "symbol": [
#                 "ETH"
#             ]
#         },
#         "metrics": [],
#         "prompt_flags": []
#     },
#     "slots": {
#         "asset_scope": {
#             "scope": "specific_asset",
#             "symbols": [
#                 "ETH"
#             ],
#             "raw_mentions": [
#                 "eth"
#             ]
#         },
#         "time_scope": {
#             "start_date": null,
#             "end_date": null,
#             "relative": null,
#             "raw_text": null
#         },
#         "timeframe": null,
#         "metrics": [],
#         "strategy_topics": [
#             "momentum"
#         ],
#         "news_filters": {
#             "categories": [
#                 "macro"
#             ],
#             "sentiments": []
#         },
#         "prompt_flags": []
#     }
# }
#
# === Prompt ===
# Give me some startegies I can use for trading.
# --- Intent ---
# {
#     "name": "strategy_info",
#     "confidence": 0.6,
#     "parameters": {
#         "raw": "Give me some startegies I can use for trading.",
#         "metrics": [],
#         "prompt_flags": []
#     },
#     "slots": {
#         "asset_scope": {
#             "scope": "all_assets",
#             "symbols": [],
#             "raw_mentions": []
#         },
#         "time_scope": {
#             "start_date": null,
#             "end_date": null,
#             "relative": null,
#             "raw_text": null
#         },
#         "timeframe": null,
#         "metrics": [],
#         "strategy_topics": [],
#         "news_filters": {
#             "categories": [],
#             "sentiments": []
#         },
#         "prompt_flags": []
#     }
# }

# %% [markdown]
# # Query planner

# %%
from src.runtime_core.test.test_query_planner import test_query_planner

test_query_planner(prompts)
# Out:
# === Prompt ===
# Which assets delivered the highest and lowest returns at Oct 15, 2025?
# --- Query Plan ---
# {
#     "specs": [
#         {
#             "table": "candles",
#             "columns": [
#                 "asset_id",
#                 "coin",
#                 "timeframe",
#                 "ts",
#                 "open",
#                 "high",
#                 "low",
#                 "close",
#                 "volume",
#                 "rsi",
#                 "ema_12",
#                 "ema_26",
#                 "macd",
#                 "macd_signal",
#                 "bb_upper",
#                 "bb_lower"
#             ],
#             "filters": {
#                 "ts_start": "2025-10-15",
#                 "ts_end": "2025-10-15",
#                 "timeframe": "1d"
#             },
#             "limit": 400
#         }
#     ],
#     "plan_steps": [
#         "Summarize price/volume action from candles data."
#     ]
# }
#
# === Prompt ===
# What coins are attractive to buy in terms of technical indicators?
# --- Query Plan ---
# {
#     "specs": [
#         {
#             "table": "candles",
#             "columns": [
#                 "asset_id",
#                 "coin",
#                 "timeframe",
#                 "ts",
#                 "open",
#                 "high",
#                 "low",
#                 "close",
#                 "volume",
#                 "rsi",
#                 "ema_12",
#                 "ema_26",
#                 "macd",
#                 "macd_signal",
#                 "bb_upper",
#                 "bb_lower"
#             ],
#             "filters": {
#                 "ts_start": "2025-10-11",
#                 "ts_end": "2025-11-10",
#                 "timeframe": "1d"
#             },
#             "limit": 400
#         },
#         {
#             "table": "indicator_signal_summary",
#             "columns": [
#                 "asset_id",
#                 "symbol",
#                 "timeframe",
#                 "evaluated_at",
#                 "buy_count",
#                 "sell_count",
#                 "neutral_count",
#                 "overall_signal",
#                 "dominant_ratio"
#             ],
#             "filters": {
#                 "timeframe": "1d",
#                 "evaluated_at_start": "2025-10-11",
#                 "evaluated_at_end": "2025-11-10"
#             },
#             "limit": 200
#         },
#         {
#             "table": "indicator_signals",
#             "columns": [
#                 "asset_id",
#                 "symbol",
#                 "timeframe",
#                 "indicator_key",
#                 "indicator_name",
#                 "indicator_value",
#                 "signal",
#                 "reason",
#                 "evaluated_at"
#             ],
#             "filters": {
#                 "evaluated_at_start": "2025-10-11",
#                 "evaluated_at_end": "2025-11-10"
#             },
#             "limit": 200
#         },
#         {
#             "table": "divergence",
#             "columns": [
#                 "asset_id",
#                 "timeframe",
#                 "start_datetime",
#                 "end_datetime",
#                 "entry_datetime",
#                 "entry_price",
#                 "divergence",
#                 "price_change",
#                 "rsi_change",
#                 "strength_score"
#             ],
#             "filters": {},
#             "limit": 200
#         },
#         {
#             "table": "news_articles",
#             "columns": [
#                 "article_id",
#                 "published_at",
#                 "source",
#                 "title",
#                 "sentiment",
#                 "categories",
#                 "tags"
#             ],
#             "filters": {
#                 "published_start": "2025-11-03",
#                 "published_end": "2025-11-10"
#             },
#             "limit": 120
#         }
#     ],
#     "plan_steps": [
#         "Step 1: Pull candles to understand trend/volatility.",
#         "Step 2: Inspect indicator_signal_summary for signals.",
#         "Step 3: Drill into indicator_signals for rule-level context.",
#         "Step 4: Check divergence table for possible momentum shifts.",
#         "Step 5: Review news to contextualize the technical read."
#     ]
# }
#
# === Prompt ===
# Summarize BTC news this week and tell me if the sentiment is positive.
# --- Query Plan ---
# {
#     "specs": [
#         {
#             "table": "news_articles",
#             "columns": [
#                 "article_id",
#                 "published_at",
#                 "source",
#                 "title",
#                 "sentiment",
#                 "categories",
#                 "tags"
#             ],
#             "filters": {
#                 "tags": [
#                     "BTC"
#                 ],
#                 "published_start": "2025-11-10",
#                 "published_end": "2025-11-10"
#             },
#             "limit": 120
#         }
#     ],
#     "plan_steps": [
#         "Aggregate news articles for the requested window.",
#         "Summarize sentiment distribution and key headlines."
#     ]
# }
#
# === Prompt ===
# What momentum strategy rules are available for ETH right now?
# --- Query Plan ---
# {
#     "specs": [
#         {
#             "table": "candles",
#             "columns": [
#                 "asset_id",
#                 "coin",
#                 "timeframe",
#                 "ts",
#                 "open",
#                 "high",
#                 "low",
#                 "close",
#                 "volume",
#                 "rsi",
#                 "ema_12",
#                 "ema_26",
#                 "macd",
#                 "macd_signal",
#                 "bb_upper",
#                 "bb_lower"
#             ],
#             "filters": {
#                 "coin": [
#                     "ETH"
#                 ],
#                 "ts_start": "2025-10-11",
#                 "ts_end": "2025-11-10",
#                 "timeframe": "1d"
#             },
#             "limit": 400
#         },
#         {
#             "table": "indicator_signal_summary",
#             "columns": [
#                 "asset_id",
#                 "symbol",
#                 "timeframe",
#                 "evaluated_at",
#                 "buy_count",
#                 "sell_count",
#                 "neutral_count",
#                 "overall_signal",
#                 "dominant_ratio"
#             ],
#             "filters": {
#                 "timeframe": "1d",
#                 "symbol": [
#                     "ETH"
#                 ],
#                 "evaluated_at_start": "2025-10-11",
#                 "evaluated_at_end": "2025-11-10"
#             },
#             "limit": 200
#         },
#         {
#             "table": "indicator_signals",
#             "columns": [
#                 "asset_id",
#                 "symbol",
#                 "timeframe",
#                 "indicator_key",
#                 "indicator_name",
#                 "indicator_value",
#                 "signal",
#                 "reason",
#                 "evaluated_at"
#             ],
#             "filters": {
#                 "symbol": [
#                     "ETH"
#                 ],
#                 "evaluated_at_start": "2025-10-11",
#                 "evaluated_at_end": "2025-11-10"
#             },
#             "limit": 200
#         },
#         {
#             "table": "divergence",
#             "columns": [
#                 "asset_id",
#                 "timeframe",
#                 "start_datetime",
#                 "end_datetime",
#                 "entry_datetime",
#                 "entry_price",
#                 "divergence",
#                 "price_change",
#                 "rsi_change",
#                 "strength_score"
#             ],
#             "filters": {},
#             "limit": 200
#         },
#         {
#             "table": "news_articles",
#             "columns": [
#                 "article_id",
#                 "published_at",
#                 "source",
#                 "title",
#                 "sentiment",
#                 "categories",
#                 "tags"
#             ],
#             "filters": {
#                 "tags": [
#                     "ETH"
#                 ],
#                 "published_start": "2025-11-03",
#                 "published_end": "2025-11-10"
#             },
#             "limit": 120
#         }
#     ],
#     "plan_steps": [
#         "Step 1: Pull candles to understand trend/volatility.",
#         "Step 2: Inspect indicator_signal_summary for signals.",
#         "Step 3: Drill into indicator_signals for rule-level context.",
#         "Step 4: Check divergence table for possible momentum shifts.",
#         "Step 5: Review news to contextualize the technical read."
#     ]
# }
#
# === Prompt ===
# Give me some startegies I can use for trading.
# --- Query Plan ---
# {
#     "specs": [
#         {
#             "table": "indicator_rules",
#             "columns": [
#                 "indicator_key",
#                 "indicator_name",
#                 "description",
#                 "required_columns",
#                 "timeframes"
#             ],
#             "filters": {},
#             "limit": 200
#         },
#         {
#             "table": "strategies",
#             "columns": [
#                 "strategy_id",
#                 "indicator_key",
#                 "name",
#                 "signal_type",
#                 "buy_condition",
#                 "sell_condition",
#                 "neutral_condition",
#                 "notes",
#                 "timeframes",
#                 "tags",
#                 "confidence_level",
#                 "source",
#                 "last_updated"
#             ],
#             "filters": {},
#             "limit": 200
#         }
#     ],
#     "plan_steps": [
#         "Enumerate indicator_rules and custom strategies matching requested topics/timeframes.",
#         "Compare rule logic against strategies table to suggest actionable playbooks."
#     ]
# }
